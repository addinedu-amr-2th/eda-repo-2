# %% [markdown]
# ## 고용형태 변화의 따른 현재 고용율

# %% [markdown]
# ## ~~ 사람인 채용정보 API~~
# ## ~~잡코리아 API 사용법~~
# ## 공공데이터 포털 https://www.data.go.kr/index.do
# #### - 한국로봇산업진흥원_로봇산업실태조사_20200423
# ## 0. 서론
# #### - 한국의 로봇 산업 현황 및 기업의 개발자 니즈 확인
# #### - 마인드맵 개제
# #### - 간트챠트 개제
# ## 1. 공공데이터 활용
# ####  - 조사 시기
# ##### - 조사 기준 시점 : 2019년 12월 31일
# ##### - 조사 대상 시점 : 2019년 1월 1일 ~ 2019년 12월 31일
# ##### - 조사 기간 : 2020년 8월 10일 ~ 2020년 11월 13일(64일간, 주말 ․ 공휴일 제외)
# ###### ~~![image.png](attachment:image.png)~~
#
# ##### ~~- 위 내용과 같이 전체 사업체 수 4,310개 중 큰 비중을 차지하는 로봇부품 및 소프트웨어 31.6%, 로봇서비스 27.3% 두가지를 중심데이터로 삼음~~
# #### 공공데이터 로봇산업 사용
# #### - 본 보고서의 내용을 전재(轉載) 또는 역재(譯載) 할 경우에는 「2019년 기준 로봇산업 실태조사   보고서 o쪽에서 전재 또는 역재」라고 기재하여야 함
#
# #### ~~- 내수+수출 :「제조업용 로봇」이 2조 6,599억원으로 30.6%, 「로봇서비스」는 1조 8,754억원으로 21.9%를 차지함~~
#
# #### ~~- 내수 : 「제조업용 로봇」이 1조 8,239억원으로 24.7%, 「로봇서비스」는 1조 8,293억원으로 24.8%를 차지함~~
# #### - 2019년 로봇 산업 인력 고용 현황
# #### - 구성 : 직무별로는 「기술직(생산)」이 18,918명으로 가장 큼
# #### - 「기술직(생산)」(18,918명) > 「연구개발」(11,416명) > 「사무직 및 기타」(11,136명) > 「영업/마케팅」(8,183명) > 「기타 단순근로」(1,093명)의 순임
# #### - 구성 : 연구개발직(11,416명)의 학력별로는 「대학교 재학/졸업」이 8,107명으로 가장 큼
# #### - 「대학교 재학/졸업」(8,107명) > 「석사 재학/수료/졸업」(2,207명) > 「박사 재학수료/졸업」(591명) > 「전문대 재학/졸업」(457명) > 「고졸 이하」(53명)의 순임
#
# ## 2. 각 취업사이트 크롤링
# ### - 로봇 검색
# #### - 잡코리아
# #### - 사람인
# ##### ~~- 할 것인지 말 것인지 모름 자율주행 검색~~
#
# ## 3. 결론
#
# ### 채용 키워드 필요지식 요구
# ### (시간 남았을 때) OECD ICT 고용 https://data.oecd.org/ict/ict-employment.htm
#
# ###### ~~공공데이터 활용안 1 - 현 교육 커리큘럼 베이스~~
# ###### ~~1. 부품 및 소프트웨어군 데이터만 활용~~
# ###### ~~2. 매출 소개 후 우리가 참가할 수 있는 로봇인력시장 안내~~
# ###### ~~3. 2019년도 고용시장 인수 시각화~~
# ###### ~~4. 크롤링 데이터를 보다 더 세분화하여 직접적으로 선택할 수 있는 상세한 직업군 제시 (경력직도 포함)~~
#
# ###### 공공데이터 활용안 2 - 공공데이터 전체 데이터
# ###### 1. 전 데이터를 시각화
# ###### 2. 2019년도 고용시장 인수 시각화
# ###### 3. 보다 더 넓은 시각으로 최소 입사 조건 및 우대 조건을 구체화 하여 발표 (로봇산업을 전부 알려 선택의 폭을 늘려줌)
